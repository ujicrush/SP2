# %%
import numpy as np
import cvxpy as cp
import matplotlib.pyplot as plt
import pickle

# %%
# ---------- Helper Functions: box uncertainty set & weighting factor ----------

# 1. Construct the box-shaped uncertainty set Ξ (axis-aligned hyper-rectangle)
def build_box_uncertainty(Z_all, qmin=0.01, qmax=0.99, eta=0.02):
    """return [ell, upp] in each dimension of Z_all"""
    low  = np.quantile(Z_all, qmin, axis=0)
    high = np.quantile(Z_all, qmax, axis=0)
    span = high - low
    ell  = low  - eta * span
    upp  = high + eta * span
    # Avoid zero-width intervals
    upp = np.maximum(upp, ell + 1e-10)
    return ell, upp

def build_box_conic_from_bounds(ell, upp, n):
    """
    Rewrite the box uncertainty set  Ξ = { (x,y): ell <= (x,y) <= upp }
    into the form C1 x + c2 y <= d   (C is the nonnegative orthant cone), for direct use of Corollary 3.3.
    Return C1 (m*n), c2 (m,), d (m,), where m = 2*(n+1)
    where n = dim(x), y is a scalar
    """
    m = 2*(n+1)
    C1 = np.zeros((m, n))
    c2 = np.zeros(m)
    d  = np.zeros(m)

    row = 0
    # upper bound： x_j <= upp_j
    for j in range(n):
        C1[row, j] = 1.0
        d[row] = upp[j]
        row += 1
    # lower bound： -x_j <= -ell_j
    for j in range(n):
        C1[row, j] = -1.0
        d[row] = -ell[j]
        row += 1
    # upper bound for y： y <= upp_y
    c2[row] = 1.0
    d[row] = upp[n]
    row += 1
    # lower bound for y： -y <= -ell_y
    c2[row] = -1.0
    d[row] = -ell[n]
    row += 1

    assert row == m
    return C1, c2, d

# 2. Compute time-dependent sample weights (exponential forgetting)
def time_weights_from_indices(time_idx, now_t, decay):
    raw = decay ** (now_t - time_idx)
    pi = raw / raw.sum()
    return pi

# 3. DRO ε-insensitive SVR
# ---------- Core：DRO-SVR following Corollary 3.3 ----------
def solve_dro_svr_cor33(X, y, C1, c2, d, pi, epsilon=60000.0, rho=0.5, use_mosek=True):
    """
    Corollary 3.3 (Support Vector Regression):
      min   λ ρ + sum_i π_i s_i
      s.t.  y_i - <w,x_i> - ε + <p_i^+, d - C1 x_i - c2 y_i> <= s_i
            <w,x_i> - y_i - ε + <p_i^-, d - C1 x_i - c2 y_i> <= s_i
            || ( C1^T p_i^+ + w ,  c2^T p_i^+ - 1 ) ||_* <= λ
            || ( C1^T p_i^- - w ,  c2^T p_i^- + 1 ) ||_* <= λ
            p_i^+, p_i^- >= 0,  s_i >= 0
    """
    N, n = X.shape
    m = C1.shape[0]  # number of constraints (2*(n+1))

    w   = cp.Variable(n)
    lam = cp.Variable(nonneg=True)
    s   = cp.Variable(N, nonneg=True)

    constraints = []

    # pre-calculate (d - C1 x_i - c2 y_i) for each sample
    D_minus_Axi_cy = (d[None, :] - X @ C1.T - np.outer(y, c2))  # (N,m)

    for i in range(N):
        p_plus_i  = cp.Variable(m, nonneg=True)
        p_minus_i = cp.Variable(m, nonneg=True)

        # y_i - <w,x_i> - ε + <p_i^+, ...> <= s_i
        lhs1_i = (y[i] - X[i] @ w - epsilon + p_plus_i @ D_minus_Axi_cy[i, :])
        constraints += [lhs1_i <= s[i]]

        # <w,x_i> - y_i - ε + <p_i^-, ...> <= s_i
        lhs2_i = (X[i] @ w - y[i] - epsilon + p_minus_i @ D_minus_Axi_cy[i, :])
        constraints += [lhs2_i <= s[i]]

        # || ( C1^T p_i^+ + w ,  c2^T p_i^+ - 1 ) ||_2 <= λ
        # || ( C1^T p_i^- - w ,  c2^T p_i^- + 1 ) ||_2 <= λ
        vec_minus = cp.hstack([C1.T @ p_minus_i - w,  c2 @ p_minus_i + 1.0])
        vec_plus = cp.hstack([C1.T @ p_plus_i + w,  c2 @ p_plus_i - 1.0])

        constraints += [
            cp.norm(vec_plus,  'inf') <= lam,
            cp.norm(vec_minus, 'inf') <= lam
        ]

    # objective：λ ρ + sum_i π_i s_i
    pi_param = cp.Parameter(N, nonneg=True, value=np.asarray(pi, float))
    obj = cp.Minimize(lam * rho + pi_param @ s)

    prob = cp.Problem(obj, constraints)
    try:
        prob.solve(solver=cp.MOSEK if use_mosek else cp.ECOS, verbose=False)
    except cp.SolverError:
        prob.solve(solver=cp.ECOS, verbose=False)

    return w.value, prob.status

# 4. Empirical ε-insensitive SVR (no regularization, time-weighted)
def solve_empirical_svr_noreg(X, y, epsilon=60000.0, sample_weights=None, use_mosek=True):
    N, n = X.shape
    w = cp.Variable(n)
    resid = y - X @ w
    loss  = cp.pos(cp.abs(resid) - epsilon)  # max(0, |r|-ε)

    if sample_weights is None:
        obj = cp.Minimize(cp.sum(loss) / N)
    else:
        sw = cp.Parameter(N, nonneg=True, value=np.asarray(sample_weights, float))
        weighted_loss = cp.sum(cp.multiply(sw, loss))
        obj = cp.Minimize(weighted_loss)

    prob = cp.Problem(obj)
    try:
        prob.solve(solver=cp.MOSEK if use_mosek else cp.ECOS, verbose=False)
    except cp.SolverError:
        prob.solve(solver=cp.ECOS, verbose=False)
    return w.value, prob.status

# 5. ε-insensitive loss
def eps_ins_loss(y_true, y_pred, eps):
    return np.maximum(0, np.abs(y_true - y_pred) - eps)

# %%
def generate_data_stream(rng, T, drift_scale_mu, drift_scale_cov, drift_scale_w, SAMPLES_PER_T):
    """Generate evolving (X,y) data stream and drifted parameters."""
    number_dimension = 5
    sigma_eps = 8000.0

    # initial setup
    mu_x = np.array([rng.uniform(80, 120),
                     rng.uniform(3, 6),
                     rng.uniform(20, 50),
                     rng.uniform(2, 8),
                     rng.uniform(0.4, 0.8)])
    A = rng.normal(0, 1, size=(number_dimension, number_dimension))
    Sigma_x = A @ A.T + np.diag([30, 1, 15, 2, 0.1])
    w_true = np.array([600, 5000, -200, -1000, 15000])

    mu_history = [mu_x.copy()]
    Sigma_history = [Sigma_x.copy()]
    w_history = [w_true.copy()]
    data_stream = []

    for t in range(T):
        mu_t = mu_history[-1]
        Sigma_t = Sigma_history[-1]
        w_t = w_history[-1]

        mu_y = float(mu_t @ w_t)
        Sigma_xy = Sigma_t @ w_t
        Sigma_yy = float(w_t.T @ Sigma_t @ w_t + sigma_eps**2)
        mu_joint = np.hstack([mu_t, mu_y])
        Sigma_joint = np.block([
            [Sigma_t, Sigma_xy.reshape(-1, 1)],
            [Sigma_xy.reshape(1, -1), np.array([[Sigma_yy]])]
        ])

        Z = rng.multivariate_normal(mu_joint, Sigma_joint, size=SAMPLES_PER_T)
        data_stream.append(Z)

        # drift next
        drift_mu = drift_scale_mu * np.abs(mu_t)
        drift_w = drift_scale_w * np.abs(w_t)
        mu_next = mu_t + rng.uniform(-drift_mu, drift_mu, size=mu_t.shape)
        Sigma_next = Sigma_t + drift_scale_cov * rng.normal(0, 1, size=Sigma_t.shape)
        Sigma_next = (Sigma_next + Sigma_next.T) / 2 + np.eye(number_dimension) * 1e-6
        w_next = w_t + rng.uniform(-drift_w, drift_w, size=w_t.shape)

        mu_history.append(mu_next)
        Sigma_history.append(Sigma_next)
        w_history.append(w_next)

    return data_stream, mu_history, Sigma_history, w_history

# %%
def single_simulation(rng, drift_scale_mu, drift_scale_cov, drift_scale_w, rho_list, decay_list, epsilon=8000.0, SAMPLES_PER_T=10):
    """
    single simulation:
      - generate T history samples and real future in t=T+1
      - consider different parameter combinations
      - return average expected loss for each parameter combination
    """
    T = 10
    data_stream, mu_hist, Sigma_hist, w_hist = generate_data_stream(rng, T, drift_scale_mu, drift_scale_cov, drift_scale_w, SAMPLES_PER_T)

    # training data: first 6 periods (flatten)
    Z_all = np.vstack(data_stream)
    X_all, y_all = Z_all[:, :-1], Z_all[:, -1]
    
    # ----------------------------------------
    # I. PRE-GENERATE the Test Scenarios (Drifts)
    # ----------------------------------------
    test_scenarios = []
    for _ in range(8):
        mu_next = mu_hist[-1] + rng.uniform(-drift_scale_mu * np.abs(mu_hist[-1]), drift_scale_mu * np.abs(mu_hist[-1]), size=mu_hist[-1].shape)
        Sigma_next = Sigma_hist[-1] + drift_scale_cov * rng.normal(0, 1, size=Sigma_hist[-1].shape)
        Sigma_next = (Sigma_next + Sigma_next.T) / 2 + np.eye(X_all.shape[1]) * 1e-6
        w_next = w_hist[-1] + rng.uniform(-drift_scale_w * np.abs(w_hist[-1]), drift_scale_w * np.abs(w_hist[-1]), size=w_hist[-1].shape)

        mu_y = float(mu_next @ w_next)
        Sigma_xy = Sigma_next @ w_next
        Sigma_yy = float(w_next.T @ Sigma_next @ w_next + 8000.0**2)
        mu_joint = np.hstack([mu_next, mu_y])
        Sigma_joint = np.block([
            [Sigma_next, Sigma_xy.reshape(-1, 1)],
            [Sigma_xy.reshape(1, -1), np.array([[Sigma_yy]])]
        ])

        Z7 = rng.multivariate_normal(mu_joint, Sigma_joint, size=SAMPLES_PER_T)
        X7, y7 = Z7[:, :-1], Z7[:, -1]
        test_scenarios.append((X7, y7))

    losses = {}

    # ----------------------------------------
    # II. Weighted dro SVR (Training)
    # ----------------------------------------
    for rho in rho_list:
        for decay in decay_list:
            # sample weights
            time_idx = np.repeat(np.arange(T), len(data_stream[0]))
            pi = time_weights_from_indices(time_idx, now_t=T-1, decay=decay)

            # DRO-SVR training
            ell, upp = build_box_uncertainty(Z_all, qmin=0.01, qmax=0.99, eta=0.02)
            C1, c2, d = build_box_conic_from_bounds(ell, upp, X_all.shape[1])
            w_hat, _ = solve_dro_svr_cor33(X_all, y_all, C1, c2, d, pi, epsilon=epsilon, rho=rho)

            loss_list = []
            for X7, y7 in test_scenarios:
                y_pred = X7 @ w_hat
                loss7 = eps_ins_loss(y7, y_pred, epsilon).mean()
                loss_list.append(loss7)
                
            losses[('dro_weighted', rho, decay)] = np.mean(loss_list)

    # ----------------------------------------
    # III. Weighted Empirical SVR (W-SAA)
    # ----------------------------------------
    for decay in decay_list:
        time_idx = np.repeat(np.arange(T), len(data_stream[0]))
        pi = time_weights_from_indices(time_idx, now_t=T-1, decay=decay)
        
        # Training
        w_hat_emp_w, _ = solve_empirical_svr_noreg(X_all, y_all, epsilon=epsilon, sample_weights=pi)

        # Testing
        loss_list = []
        for X7, y7 in test_scenarios:
            y_pred = X7 @ w_hat_emp_w
            loss7 = eps_ins_loss(y7, y_pred, epsilon).mean()
            loss_list.append(loss7)
        
        losses[('empirical_weighted', 0.0, decay)] = np.mean(loss_list)

    # ----------------------------------------
    # IV. Unweighted Empirical SVR (SAA)
    # ----------------------------------------
    w_hat_emp_unw, _ = solve_empirical_svr_noreg(X_all, y_all, epsilon=epsilon, sample_weights=None)
    loss_list = []
    for X7, y7 in test_scenarios:
        y_pred = X7 @ w_hat_emp_unw
        loss7 = eps_ins_loss(y7, y_pred, epsilon).mean()
        loss_list.append(loss7)
        
    losses[('empirical_unweighted', 0.0, 0.0)] = np.mean(loss_list)

    return losses # Return all calculated losses

# %%
def run_multiple_simulations(num_runs=5, drift_scale_mu=None, drift_scale_cov=0.02, drift_scale_w=0.025,
                             rho_list=None, decay_list=None, epsilon=8000.0, SAMPLES_PER_T=10):
    base_rng = np.random.default_rng(seed=42)
    
    dro_losses = []
    emp_weighted_losses = []
    emp_unweighted_losses = []

    for run in range(num_runs):
        print(f"Simulation {run+1}/{num_runs}")
        rng = np.random.default_rng(base_rng.integers(1e9)) 
        
        # results now contains all ('method', rho, decay) keys
        results = single_simulation(rng, drift_scale_mu, drift_scale_cov, drift_scale_w, rho_list, decay_list, epsilon=epsilon, SAMPLES_PER_T=SAMPLES_PER_T)

        # 1. DRO-SVR: find ex-post optimal (rho, decay) among DRO results
        dro_results = {k: v for k, v in results.items() if k[0] == 'dro_weighted'} 
        best_dro_param = min(dro_results, key=dro_results.get) 
        best_dro_loss = dro_results[best_dro_param]
        dro_losses.append(best_dro_loss)
        print(f"  → DRO-SVR Best param: ρ={best_dro_param[1]}, decay={best_dro_param[2]}, loss={best_dro_loss:.2f}")

        # 2. Weighted Empirical SVR (W-SAA): find ex-post optimal decay
        emp_w_results = {k: v for k, v in results.items() if k[0] == 'empirical_weighted'}
        best_emp_w_param = min(emp_w_results, key=emp_w_results.get)
        best_emp_w_loss = emp_w_results[best_emp_w_param]
        emp_weighted_losses.append(best_emp_w_loss)
        print(f"  → W-SAA Best param: decay={best_emp_w_param[2]}, loss={best_emp_w_loss:.2f}")
        
        # 3. Unweighted Empirical SVR (Unweighted SAA)
        unw_loss = results[('empirical_unweighted', 0.0, 0.0)]
        emp_unweighted_losses.append(unw_loss)
        print(f"  → Unweighted SAA loss: {unw_loss:.2f}")

    return {
        'DRO-SVR': np.array(dro_losses),
        'W-SAA': np.array(emp_weighted_losses),
        'SAA': np.array(emp_unweighted_losses)
    }

# %%
rho_list = [0.05, 0.1, 0.5, 1.0]
decay_list = [0.65, 0.75, 0.85, 0.95]
drift_param_list = np.logspace(-4, -1, num=10)

avg_results_all_methods = {'DRO-SVR': {}, 'W-SAA': {}, 'SAA': {}}
sem_results_all_methods = {'DRO-SVR': {}, 'W-SAA': {}, 'SAA': {}}

for dp in drift_param_list:
    print(f"\nRunning simulations for drift parameter {dp:.1e}...")

    losses_all = run_multiple_simulations(
        num_runs=10,
        drift_scale_mu=dp,
        drift_scale_cov=dp,
        drift_scale_w=dp,
        rho_list=rho_list,
        decay_list=decay_list,
        epsilon=8000.0,
        SAMPLES_PER_T=20
    )

    dro_losses = np.array(losses_all['DRO-SVR'])
    w_saa_losses = np.array(losses_all['W-SAA'])
    saa_losses = np.array(losses_all['SAA'])

    n = len(dro_losses)
    baseline_mean = w_saa_losses.mean()

    dro_rel = dro_losses / baseline_mean
    w_saa_rel = w_saa_losses / baseline_mean
    saa_rel = saa_losses / baseline_mean

    avg_results_all_methods['DRO-SVR'][dp] = dro_rel.mean()
    sem_results_all_methods['DRO-SVR'][dp] = dro_rel.std(ddof=1) / np.sqrt(n)

    avg_results_all_methods['W-SAA'][dp] = w_saa_rel.mean()
    sem_results_all_methods['W-SAA'][dp] = w_saa_rel.std(ddof=1) / np.sqrt(n)

    avg_results_all_methods['SAA'][dp] = saa_rel.mean()
    sem_results_all_methods['SAA'][dp] = saa_rel.std(ddof=1) / np.sqrt(n)

    print(
        f"Drift={dp:.1e} | "
        f"DRO mean={dro_rel.mean():.3f}±{dro_rel.std(ddof=1)/np.sqrt(n):.3f}, "
        f"W-SAA mean={w_saa_rel.mean():.3f}±{w_saa_rel.std(ddof=1)/np.sqrt(n):.3f}, "
        f"SAA mean={saa_rel.mean():.3f}±{saa_rel.std(ddof=1)/np.sqrt(n):.3f}"
    )

# save results
with open("simulation_results_1order.pkl", "wb") as f:
    pickle.dump({
        "avg": avg_results_all_methods,
        "sem": sem_results_all_methods,
        "drift_list": drift_param_list
    }, f)
# Out:
# Running simulations for drift parameter 1.0e-04...
# Simulation 1/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.85, loss=1355.89
#   → W-SAA Best param: decay=0.95, loss=1390.36
#   → Unweighted SAA loss: 1390.74
# Simulation 2/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.65, loss=1653.02
#   → W-SAA Best param: decay=0.95, loss=1666.75
#   → Unweighted SAA loss: 1645.60
# Simulation 3/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.75, loss=1935.30
#   → W-SAA Best param: decay=0.65, loss=2077.90
#   → Unweighted SAA loss: 2121.41
# Simulation 4/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.95, loss=1167.13
#   → W-SAA Best param: decay=0.95, loss=1262.53
#   → Unweighted SAA loss: 1211.49
# Simulation 5/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.65, loss=1554.64
#   → W-SAA Best param: decay=0.65, loss=1466.20
#   → Unweighted SAA loss: 1506.36
# Simulation 6/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.85, loss=1556.65
#   → W-SAA Best param: decay=0.95, loss=1464.84
#   → Unweighted SAA loss: 1473.57
# Simulation 7/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=1341.88
#   → W-SAA Best param: decay=0.95, loss=1425.61
#   → Unweighted SAA loss: 1424.92
# Simulation 8/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=1442.17
#   → W-SAA Best param: decay=0.95, loss=1400.93
#   → Unweighted SAA loss: 1407.91
# Simulation 9/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=1318.83
#   → W-SAA Best param: decay=0.95, loss=1312.44
#   → Unweighted SAA loss: 1307.95
# Simulation 10/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.95, loss=1324.99
#   → W-SAA Best param: decay=0.65, loss=1336.88
#   → Unweighted SAA loss: 1373.39
# Drift=1.0e-04 | DRO mean=0.990±0.047, W-SAA mean=1.000±0.051, SAA mean=1.004±0.054
#
# Running simulations for drift parameter 2.2e-04...
# Simulation 1/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.85, loss=1358.29
#   → W-SAA Best param: decay=0.95, loss=1391.10
#   → Unweighted SAA loss: 1387.83
# Simulation 2/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.65, loss=1654.00
#   → W-SAA Best param: decay=0.95, loss=1667.65
#   → Unweighted SAA loss: 1647.44
# Simulation 3/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.75, loss=1935.60
#   → W-SAA Best param: decay=0.65, loss=2078.07
#   → Unweighted SAA loss: 2121.37
# Simulation 4/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.95, loss=1166.67
#   → W-SAA Best param: decay=0.95, loss=1267.05
#   → Unweighted SAA loss: 1211.12
# Simulation 5/10
# C:\Users\11864\AppData\Local\Temp\ipykernel_30972\684457634.py:34: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   Z7 = rng.multivariate_normal(mu_joint, Sigma_joint, size=SAMPLES_PER_T)
#   → DRO-SVR Best param: ρ=0.05, decay=0.65, loss=1554.73
#   → W-SAA Best param: decay=0.65, loss=1466.40
#   → Unweighted SAA loss: 1505.26
# Simulation 6/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.85, loss=1556.23
#   → W-SAA Best param: decay=0.95, loss=1465.72
#   → Unweighted SAA loss: 1473.64
# Simulation 7/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=1341.87
#   → W-SAA Best param: decay=0.95, loss=1426.45
#   → Unweighted SAA loss: 1425.97
# Simulation 8/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=1442.23
#   → W-SAA Best param: decay=0.95, loss=1400.38
#   → Unweighted SAA loss: 1406.83
# Simulation 9/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=1318.59
#   → W-SAA Best param: decay=0.95, loss=1312.49
#   → Unweighted SAA loss: 1307.98
# Simulation 10/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.95, loss=1325.11
#   → W-SAA Best param: decay=0.65, loss=1336.71
#   → Unweighted SAA loss: 1373.74
# Drift=2.2e-04 | DRO mean=0.989±0.047, W-SAA mean=1.000±0.051, SAA mean=1.003±0.054
#
# Running simulations for drift parameter 4.6e-04...
# Simulation 1/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=1372.37
#   → W-SAA Best param: decay=0.95, loss=1392.69
#   → Unweighted SAA loss: 1387.65
# Simulation 2/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.65, loss=1656.19
#   → W-SAA Best param: decay=0.95, loss=1669.79
#   → Unweighted SAA loss: 1651.64
# Simulation 3/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.75, loss=1936.24
#   → W-SAA Best param: decay=0.65, loss=2078.46
#   → Unweighted SAA loss: 2121.27
# Simulation 4/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.95, loss=1165.68
#   → W-SAA Best param: decay=0.95, loss=1267.11
#   → Unweighted SAA loss: 1209.90
# Simulation 5/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.65, loss=1554.93
#   → W-SAA Best param: decay=0.65, loss=1466.43
#   → Unweighted SAA loss: 1502.90
# Simulation 6/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.85, loss=1555.33
#   → W-SAA Best param: decay=0.95, loss=1467.61
#   → Unweighted SAA loss: 1473.80
# Simulation 7/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=1342.05
#   → W-SAA Best param: decay=0.95, loss=1428.47
#   → Unweighted SAA loss: 1428.24
# Simulation 8/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=1442.36
#   → W-SAA Best param: decay=0.95, loss=1399.19
#   → Unweighted SAA loss: 1404.52
# Simulation 9/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=1335.07
#   → W-SAA Best param: decay=0.95, loss=1312.62
#   → Unweighted SAA loss: 1308.05
# Simulation 10/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.95, loss=1325.39
#   → W-SAA Best param: decay=0.65, loss=1336.34
#   → Unweighted SAA loss: 1374.50
# Drift=4.6e-04 | DRO mean=0.991±0.046, W-SAA mean=1.000±0.051, SAA mean=1.003±0.054
#
# Running simulations for drift parameter 1.0e-03...
# Simulation 1/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.95, loss=1435.13
#   → W-SAA Best param: decay=0.95, loss=1396.75
#   → Unweighted SAA loss: 1393.04
# Simulation 2/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.65, loss=1660.90
#   → W-SAA Best param: decay=0.95, loss=1674.45
#   → Unweighted SAA loss: 1657.59
# Simulation 3/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.75, loss=1938.01
#   → W-SAA Best param: decay=0.65, loss=2079.27
#   → Unweighted SAA loss: 2121.08
# Simulation 4/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.95, loss=1163.85
#   → W-SAA Best param: decay=0.95, loss=1252.35
#   → Unweighted SAA loss: 1209.03
# Simulation 5/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.75, loss=1535.61
#   → W-SAA Best param: decay=0.65, loss=1466.04
#   → Unweighted SAA loss: 1498.35
# Simulation 6/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.85, loss=1553.41
#   → W-SAA Best param: decay=0.95, loss=1471.70
#   → Unweighted SAA loss: 1474.37
# Simulation 7/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=1342.90
#   → W-SAA Best param: decay=0.95, loss=1432.36
#   → Unweighted SAA loss: 1430.92
# Simulation 8/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=1442.63
#   → W-SAA Best param: decay=0.95, loss=1396.63
#   → Unweighted SAA loss: 1399.56
# Simulation 9/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=1333.81
#   → W-SAA Best param: decay=0.95, loss=1313.17
#   → Unweighted SAA loss: 1308.63
# Simulation 10/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.95, loss=1325.98
#   → W-SAA Best param: decay=0.65, loss=1336.22
#   → Unweighted SAA loss: 1375.77
# Drift=1.0e-03 | DRO mean=0.994±0.046, W-SAA mean=1.000±0.051, SAA mean=1.003±0.054
#
# Running simulations for drift parameter 2.2e-03...
# Simulation 1/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.85, loss=1435.53
#   → W-SAA Best param: decay=0.95, loss=1398.84
#   → Unweighted SAA loss: 1399.13
# Simulation 2/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.65, loss=1669.86
#   → W-SAA Best param: decay=0.95, loss=1684.35
#   → Unweighted SAA loss: 1670.43
# Simulation 3/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.95, loss=1941.24
#   → W-SAA Best param: decay=0.65, loss=2082.31
#   → Unweighted SAA loss: 2122.12
# Simulation 4/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.95, loss=1160.99
#   → W-SAA Best param: decay=0.95, loss=1257.45
#   → Unweighted SAA loss: 1225.83
# Simulation 5/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.75, loss=1540.42
#   → W-SAA Best param: decay=0.65, loss=1465.97
#   → Unweighted SAA loss: 1481.27
# Simulation 6/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.85, loss=1550.06
#   → W-SAA Best param: decay=0.95, loss=1482.11
#   → Unweighted SAA loss: 1478.84
# Simulation 7/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=1345.06
#   → W-SAA Best param: decay=0.95, loss=1440.92
#   → Unweighted SAA loss: 1434.26
# Simulation 8/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=1441.90
#   → W-SAA Best param: decay=0.95, loss=1389.06
#   → Unweighted SAA loss: 1389.15
# Simulation 9/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=1332.69
#   → W-SAA Best param: decay=0.95, loss=1313.98
#   → Unweighted SAA loss: 1318.54
# Simulation 10/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.95, loss=1325.91
#   → W-SAA Best param: decay=0.85, loss=1347.21
#   → Unweighted SAA loss: 1378.48
# Drift=2.2e-03 | DRO mean=0.992±0.046, W-SAA mean=1.000±0.051, SAA mean=1.002±0.053
#
# Running simulations for drift parameter 4.6e-03...
# Simulation 1/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.85, loss=1444.72
#   → W-SAA Best param: decay=0.95, loss=1423.96
#   → Unweighted SAA loss: 1423.96
# Simulation 2/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.65, loss=1689.87
#   → W-SAA Best param: decay=0.95, loss=1690.26
#   → Unweighted SAA loss: 1693.51
# Simulation 3/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.95, loss=1949.16
#   → W-SAA Best param: decay=0.65, loss=2077.16
#   → Unweighted SAA loss: 2125.14
# Simulation 4/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.95, loss=1159.46
#   → W-SAA Best param: decay=0.95, loss=1250.97
#   → Unweighted SAA loss: 1238.23
# Simulation 5/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.65, loss=1508.57
#   → W-SAA Best param: decay=0.65, loss=1468.98
#   → Unweighted SAA loss: 1484.48
# Simulation 6/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.85, loss=1546.07
#   → W-SAA Best param: decay=0.95, loss=1490.58
#   → Unweighted SAA loss: 1471.49
# Simulation 7/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=1347.62
#   → W-SAA Best param: decay=0.95, loss=1431.21
#   → Unweighted SAA loss: 1430.12
# Simulation 8/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=1442.96
#   → W-SAA Best param: decay=0.95, loss=1376.92
#   → Unweighted SAA loss: 1387.08
# Simulation 9/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=1326.31
#   → W-SAA Best param: decay=0.95, loss=1318.08
#   → Unweighted SAA loss: 1334.60
# Simulation 10/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.95, loss=1329.57
#   → W-SAA Best param: decay=0.65, loss=1338.96
#   → Unweighted SAA loss: 1377.65
# Drift=4.6e-03 | DRO mean=0.992±0.047, W-SAA mean=1.000±0.051, SAA mean=1.007±0.053
#
# Running simulations for drift parameter 1.0e-02...
# Simulation 1/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.75, loss=1527.13
#   → W-SAA Best param: decay=0.95, loss=1518.51
#   → Unweighted SAA loss: 1518.51
# Simulation 2/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.65, loss=1711.39
#   → W-SAA Best param: decay=0.65, loss=1756.48
#   → Unweighted SAA loss: 1759.22
# Simulation 3/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.95, loss=1976.39
#   → W-SAA Best param: decay=0.95, loss=2068.06
#   → Unweighted SAA loss: 2103.36
# Simulation 4/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.95, loss=1203.66
#   → W-SAA Best param: decay=0.95, loss=1272.66
#   → Unweighted SAA loss: 1289.90
# Simulation 5/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.75, loss=1573.69
#   → W-SAA Best param: decay=0.95, loss=1477.97
#   → Unweighted SAA loss: 1526.39
# Simulation 6/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.85, loss=1572.20
#   → W-SAA Best param: decay=0.95, loss=1481.19
#   → Unweighted SAA loss: 1481.19
# Simulation 7/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.95, loss=1358.55
#   → W-SAA Best param: decay=0.95, loss=1426.63
#   → Unweighted SAA loss: 1418.38
# Simulation 8/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.85, loss=1434.21
#   → W-SAA Best param: decay=0.95, loss=1367.06
#   → Unweighted SAA loss: 1373.99
# Simulation 9/10
# C:\Users\11864\AppData\Local\Temp\ipykernel_30972\805704945.py:35: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   Z = rng.multivariate_normal(mu_joint, Sigma_joint, size=SAMPLES_PER_T)
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=1350.85
#   → W-SAA Best param: decay=0.95, loss=1338.73
#   → Unweighted SAA loss: 1337.52
# Simulation 10/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.85, loss=1330.99
#   → W-SAA Best param: decay=0.75, loss=1339.55
#   → Unweighted SAA loss: 1376.07
# Drift=1.0e-02 | DRO mean=0.999±0.047, W-SAA mean=1.000±0.050, SAA mean=1.009±0.051
#
# Running simulations for drift parameter 2.2e-02...
# Simulation 1/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.85, loss=1677.51
#   → W-SAA Best param: decay=0.65, loss=1728.86
#   → Unweighted SAA loss: 1862.58
# Simulation 2/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.65, loss=1820.23
#   → W-SAA Best param: decay=0.75, loss=1774.88
#   → Unweighted SAA loss: 1832.19
# Simulation 3/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.85, loss=2078.46
#   → W-SAA Best param: decay=0.85, loss=2128.72
#   → Unweighted SAA loss: 2137.72
# Simulation 4/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.95, loss=1413.77
#   → W-SAA Best param: decay=0.95, loss=1550.73
#   → Unweighted SAA loss: 1585.63
# Simulation 5/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.75, loss=1411.55
#   → W-SAA Best param: decay=0.85, loss=1385.60
#   → Unweighted SAA loss: 1432.30
# Simulation 6/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.85, loss=1607.76
#   → W-SAA Best param: decay=0.85, loss=1513.36
#   → Unweighted SAA loss: 1533.23
# Simulation 7/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.85, loss=1417.85
#   → W-SAA Best param: decay=0.95, loss=1484.83
#   → Unweighted SAA loss: 1493.32
# Simulation 8/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.75, loss=1420.10
#   → W-SAA Best param: decay=0.95, loss=1374.37
#   → Unweighted SAA loss: 1404.50
# Simulation 9/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.95, loss=1406.67
#   → W-SAA Best param: decay=0.95, loss=1376.14
#   → Unweighted SAA loss: 1388.09
# Simulation 10/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.65, loss=1352.43
#   → W-SAA Best param: decay=0.95, loss=1392.55
#   → Unweighted SAA loss: 1393.40
# Drift=2.2e-02 | DRO mean=0.993±0.048, W-SAA mean=1.000±0.049, SAA mean=1.022±0.051
#
# Running simulations for drift parameter 4.6e-02...
# Simulation 1/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.65, loss=2089.12
#   → W-SAA Best param: decay=0.65, loss=2092.16
#   → Unweighted SAA loss: 2966.92
# Simulation 2/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.65, loss=2251.72
#   → W-SAA Best param: decay=0.65, loss=2147.14
#   → Unweighted SAA loss: 2278.31
# Simulation 3/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.75, loss=2427.56
#   → W-SAA Best param: decay=0.65, loss=2412.30
#   → Unweighted SAA loss: 2510.68
# Simulation 4/10
#   → DRO-SVR Best param: ρ=0.5, decay=0.65, loss=2269.80
#   → W-SAA Best param: decay=0.75, loss=2723.37
#   → Unweighted SAA loss: 3086.19
# Simulation 5/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.65, loss=1693.94
#   → W-SAA Best param: decay=0.65, loss=1647.89
#   → Unweighted SAA loss: 1710.77
# Simulation 6/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.75, loss=1761.74
#   → W-SAA Best param: decay=0.65, loss=1679.23
#   → Unweighted SAA loss: 1840.31
# Simulation 7/10
#   → DRO-SVR Best param: ρ=0.5, decay=0.95, loss=1450.97
#   → W-SAA Best param: decay=0.95, loss=1975.70
#   → Unweighted SAA loss: 1938.47
# Simulation 8/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.65, loss=1430.06
#   → W-SAA Best param: decay=0.65, loss=1409.06
#   → Unweighted SAA loss: 1573.54
# Simulation 9/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.85, loss=1344.52
#   → W-SAA Best param: decay=0.75, loss=1327.04
#   → Unweighted SAA loss: 1337.60
# Simulation 10/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.85, loss=1531.81
#   → W-SAA Best param: decay=0.65, loss=1524.15
#   → Unweighted SAA loss: 1583.07
# Drift=4.6e-02 | DRO mean=0.964±0.067, W-SAA mean=1.000±0.076, SAA mean=1.100±0.101
#
# Running simulations for drift parameter 1.0e-01...
# Simulation 1/10
#   → DRO-SVR Best param: ρ=0.5, decay=0.65, loss=3146.79
#   → W-SAA Best param: decay=0.65, loss=3257.36
#   → Unweighted SAA loss: 4832.69
# Simulation 2/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.65, loss=2717.51
#   → W-SAA Best param: decay=0.65, loss=2963.70
#   → Unweighted SAA loss: 3635.84
# Simulation 3/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.65, loss=3608.97
#   → W-SAA Best param: decay=0.65, loss=3506.09
#   → Unweighted SAA loss: 4430.61
# Simulation 4/10
#   → DRO-SVR Best param: ρ=0.5, decay=0.75, loss=3076.22
#   → W-SAA Best param: decay=0.65, loss=4589.62
#   → Unweighted SAA loss: 5708.32
# Simulation 5/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.65, loss=2477.97
#   → W-SAA Best param: decay=0.65, loss=2541.60
#   → Unweighted SAA loss: 2925.74
# Simulation 6/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.65, loss=2508.60
#   → W-SAA Best param: decay=0.65, loss=2435.93
#   → Unweighted SAA loss: 3243.98
# Simulation 7/10
#   → DRO-SVR Best param: ρ=0.5, decay=0.95, loss=2013.00
#   → W-SAA Best param: decay=0.95, loss=2994.63
#   → Unweighted SAA loss: 3239.67
# Simulation 8/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.65, loss=1996.29
#   → W-SAA Best param: decay=0.65, loss=1876.01
#   → Unweighted SAA loss: 2385.45
# Simulation 9/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.95, loss=2007.08
#   → W-SAA Best param: decay=0.95, loss=2116.78
#   → Unweighted SAA loss: 2077.55
# Simulation 10/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.95, loss=2353.42
#   → W-SAA Best param: decay=0.75, loss=2414.96
#   → Unweighted SAA loss: 2486.90
# Drift=1.0e-01 | DRO mean=0.903±0.060, W-SAA mean=1.000±0.087, SAA mean=1.218±0.129

# %%
with open("simulation_results_1order.pkl", "rb") as f:
    data = pickle.load(f)

drift_params_array = np.array(list(avg_results_all_methods['DRO-SVR'].keys()))

dro_mean = np.array(list(avg_results_all_methods['DRO-SVR'].values()))
w_saa_mean = np.array(list(avg_results_all_methods['W-SAA'].values()))
saa_mean = np.array(list(avg_results_all_methods['SAA'].values()))

dro_sem = np.array(list(sem_results_all_methods['DRO-SVR'].values()))
w_saa_sem = np.array(list(sem_results_all_methods['W-SAA'].values()))
saa_sem = np.array(list(sem_results_all_methods['SAA'].values()))

plt.figure(figsize=(8,5))

# DRO-SVR
plt.plot(drift_params_array, dro_mean, marker='o', color='tab:blue', label='DRO-SVR')
plt.fill_between(drift_params_array, dro_mean - dro_sem, dro_mean + dro_sem,
                 color='tab:blue', alpha=0.2)

# W-SAA
plt.plot(drift_params_array, w_saa_mean, marker='s', linestyle='--',
         color='tab:orange', label='W-SAA (Weighted Empirical, Base)')
plt.fill_between(drift_params_array, w_saa_mean - w_saa_sem, w_saa_mean + w_saa_sem,
                 color='tab:orange', alpha=0.2)

# SAA
plt.plot(drift_params_array, saa_mean, marker='^', color='tab:green', label='SAA (Unweighted Empirical)')
plt.fill_between(drift_params_array, saa_mean - saa_sem, saa_mean + saa_sem,
                 color='tab:green', alpha=0.2)

plt.axhline(y=1.0, color='gray', linestyle=':', linewidth=1)
plt.xscale('log')
plt.xlim(min(drift_params_array), max(drift_params_array))
plt.xlabel("Drift parameter intensity")
plt.ylabel("Average Ex-Post Optimal Loss (relative to W-SAA)")
plt.title("Performance Comparison vs Drift Strength (Relative Loss)")
plt.legend()
plt.grid(True, which='both', ls=':')
plt.show()
