# %%
import numpy as np
import cvxpy as cp
import matplotlib.pyplot as plt
import pickle

# %%
# ---------- Helper Functions: box uncertainty set & weighting factor ----------

# 1. Construct the box-shaped uncertainty set Ξ (axis-aligned hyper-rectangle)
def build_box_uncertainty(Z_all, qmin=0.01, qmax=0.99, eta=0.02):
    """return [ell, upp] in each dimension of Z_all"""
    low  = np.quantile(Z_all, qmin, axis=0)
    high = np.quantile(Z_all, qmax, axis=0)
    span = high - low
    ell  = low  - eta * span
    upp  = high + eta * span
    # Avoid zero-width intervals
    upp = np.maximum(upp, ell + 1e-10)
    return ell, upp

def build_box_conic_from_bounds(ell, upp, n):
    """
    Rewrite the box uncertainty set  Ξ = { (x,y): ell <= (x,y) <= upp }
    into the form C1 x + c2 y <= d   (C is the nonnegative orthant cone), for direct use of Corollary 3.3.
    Return C1 (m*n), c2 (m,), d (m,), where m = 2*(n+1)
    where n = dim(x), y is a scalar
    """
    m = 2*(n+1)
    C1 = np.zeros((m, n))
    c2 = np.zeros(m)
    d  = np.zeros(m)

    row = 0
    # upper bound： x_j <= upp_j
    for j in range(n):
        C1[row, j] = 1.0
        d[row] = upp[j]
        row += 1
    # lower bound： -x_j <= -ell_j
    for j in range(n):
        C1[row, j] = -1.0
        d[row] = -ell[j]
        row += 1
    # upper bound for y： y <= upp_y
    c2[row] = 1.0
    d[row] = upp[n]
    row += 1
    # lower bound for y： -y <= -ell_y
    c2[row] = -1.0
    d[row] = -ell[n]
    row += 1

    assert row == m
    return C1, c2, d

# 2a. Compute time-dependent sample weights (exponential forgetting)
def time_weights_from_indices(time_idx, now_t, decay):
    raw = decay ** (now_t - time_idx)
    pi = raw / raw.sum()
    return pi

# 2b. Optimal weights according to Proposition 2 (for p = 1)
def optimal_weights_prop2(T, eps_over_rho):
    """
    Proposition 2 optimal weights for p = 1:
    - T = history length
    - eps_over_rho = ε/ρ in the paper, where eps in our code is ambuiguity radius, rho is the wasserstein distance between Pt and Pt+1
    Return weights w of length T
    """

    # s = floor(eps / rho)
    s = int(np.floor(eps_over_rho))
    s = max(1, min(s, T))  # truncate to [1, T]
    
    w = np.zeros(T)
    denom = s * (2 * eps_over_rho - s - 1)
    
    for t in range(T - s, T):
        # t runs from T-s to T-1  (0-index)
        w[t] = 2 * ((eps_over_rho) + (t+1) - T - 1) / denom

    return w

# 3. DRO ε-insensitive SVR
# ---------- Core：DRO-SVR following Corollary 3.3 ----------
def solve_dro_svr_cor33(X, y, C1, c2, d, pi, epsilon=60000.0, rho=0.5, use_mosek=True):
    """
    Corollary 3.3 (Support Vector Regression):
      min   λ ρ + sum_i π_i s_i
      s.t.  y_i - <w,x_i> - ε + <p_i^+, d - C1 x_i - c2 y_i> <= s_i
            <w,x_i> - y_i - ε + <p_i^-, d - C1 x_i - c2 y_i> <= s_i
            || ( C1^T p_i^+ + w ,  c2^T p_i^+ - 1 ) ||_* <= λ
            || ( C1^T p_i^- - w ,  c2^T p_i^- + 1 ) ||_* <= λ
            p_i^+, p_i^- >= 0,  s_i >= 0
    """
    N, n = X.shape
    m = C1.shape[0]  # number of constraints (2*(n+1))

    w   = cp.Variable(n)
    lam = cp.Variable(nonneg=True)
    s   = cp.Variable(N, nonneg=True)

    constraints = []

    # pre-calculate (d - C1 x_i - c2 y_i) for each sample
    D_minus_Axi_cy = (d[None, :] - X @ C1.T - np.outer(y, c2))  # (N,m)

    for i in range(N):
        p_plus_i  = cp.Variable(m, nonneg=True)
        p_minus_i = cp.Variable(m, nonneg=True)

        # y_i - <w,x_i> - ε + <p_i^+, ...> <= s_i
        lhs1_i = (y[i] - X[i] @ w - epsilon + p_plus_i @ D_minus_Axi_cy[i, :])
        constraints += [lhs1_i <= s[i]]

        # <w,x_i> - y_i - ε + <p_i^-, ...> <= s_i
        lhs2_i = (X[i] @ w - y[i] - epsilon + p_minus_i @ D_minus_Axi_cy[i, :])
        constraints += [lhs2_i <= s[i]]

        # || ( C1^T p_i^+ + w ,  c2^T p_i^+ - 1 ) ||_2 <= λ
        # || ( C1^T p_i^- - w ,  c2^T p_i^- + 1 ) ||_2 <= λ
        vec_minus = cp.hstack([C1.T @ p_minus_i - w,  c2 @ p_minus_i + 1.0])
        vec_plus = cp.hstack([C1.T @ p_plus_i + w,  c2 @ p_plus_i - 1.0])

        constraints += [
            cp.norm(vec_plus,  'inf') <= lam,
            cp.norm(vec_minus, 'inf') <= lam
        ]

    # objective：λ ρ + sum_i π_i s_i
    pi_param = cp.Parameter(N, nonneg=True, value=np.asarray(pi, float))
    obj = cp.Minimize(lam * rho + pi_param @ s)

    prob = cp.Problem(obj, constraints)
    try:
        prob.solve(solver=cp.MOSEK if use_mosek else cp.ECOS, verbose=False)
    except cp.SolverError:
        prob.solve(solver=cp.ECOS, verbose=False)

    return w.value, prob.status

# 4. Empirical ε-insensitive SVR (no regularization, time-weighted)
def solve_empirical_svr_noreg(X, y, epsilon=60000.0, sample_weights=None, use_mosek=True):
    N, n = X.shape
    w = cp.Variable(n)
    resid = y - X @ w
    loss  = cp.pos(cp.abs(resid) - epsilon)  # max(0, |r|-ε)

    if sample_weights is None:
        obj = cp.Minimize(cp.sum(loss) / N)
    else:
        sw = cp.Parameter(N, nonneg=True, value=np.asarray(sample_weights, float))
        weighted_loss = cp.sum(cp.multiply(sw, loss))
        obj = cp.Minimize(weighted_loss)

    prob = cp.Problem(obj)
    try:
        prob.solve(solver=cp.MOSEK if use_mosek else cp.ECOS, verbose=False)
    except cp.SolverError:
        prob.solve(solver=cp.ECOS, verbose=False)
    return w.value, prob.status

# 5. ε-insensitive loss
def eps_ins_loss(y_true, y_pred, eps):
    return np.maximum(0, np.abs(y_true - y_pred) - eps)

# %%
def generate_data_stream(rng, T, alpha_mu, alpha_sigma, alpha_d, SAMPLES_PER_T):
    """Generate evolving (X,y) data stream and drifted parameters."""
    number_dimension = 5
    sigma_eps = 8000.0

    # initial setup
    mu_x = np.array([rng.uniform(80, 120),
                     rng.uniform(3, 6),
                     rng.uniform(20, 50),
                     rng.uniform(2, 8),
                     rng.uniform(0.4, 0.8)])
    A = rng.normal(0, 1, size=(number_dimension, number_dimension))
    Sigma_x = A @ A.T + np.diag([30, 1, 15, 2, 0.1])
    d_true = np.array([600, 5000, -200, -1000, 15000])

    mu_history = [mu_x.copy()]
    Sigma_history = [Sigma_x.copy()]
    d_history = [d_true.copy()]
    data_stream = []

    for t in range(T):
        mu_t = mu_history[-1]
        Sigma_t = Sigma_history[-1]
        d_t = d_history[-1]

        # --- Joint Data Generation ---
        mu_y = float(mu_t @ d_t)
        Sigma_xy = Sigma_t @ d_t
        Sigma_yy = float(d_t.T @ Sigma_t @ d_t + sigma_eps**2)
        
        mu_joint = np.hstack([mu_t, mu_y])
        Sigma_joint = np.block([
            [Sigma_t, Sigma_xy.reshape(-1, 1)],
            [Sigma_xy.reshape(1, -1), np.array([[Sigma_yy]])]
        ])

        Z = rng.multivariate_normal(mu_joint, Sigma_joint, size=SAMPLES_PER_T)
        data_stream.append(Z)

        # --- Drift to next step (t+1) ---
        # (1) Feature mean drift (alpha_mu)
        # Delta_t^(mu) ~ Uniform(-alpha_mu |mu_t|, +alpha_mu |mu_t|)
        drift_mu_range = alpha_mu * np.abs(mu_t)
        mu_next = mu_t + rng.uniform(-drift_mu_range, drift_mu_range, size=mu_t.shape)

        # (2) Dependency vector drift (alpha_d)
        # Delta_t^(d) ~ Uniform(-alpha_d |d_t|, +alpha_d |d_t|)
        drift_d_range = alpha_d * np.abs(d_t)
        d_next = d_t + rng.uniform(-drift_d_range, drift_d_range, size=d_t.shape)

        # (3) Covariance drift (alpha_Sigma)
        # G_t,ij ~ N(0, alpha_Sigma^2)
        G_t = rng.normal(0, alpha_sigma, size=Sigma_t.shape)
        # D_t = 1/2 * (G_t + G_t^T)
        D_t = 0.5 * (G_t + G_t.T)
        # Sigma_{t+1} = (I + 1/2 * D_t) * Sigma_t * (I + 1/2 * D_t)^T
        I_plus_half_D = np.eye(number_dimension) + 0.5 * D_t
        Sigma_next = I_plus_half_D @ Sigma_t @ I_plus_half_D.T
        Sigma_next = (Sigma_next + Sigma_next.T) / 2 # Already symmetric by construction
        
        mu_history.append(mu_next)
        Sigma_history.append(Sigma_next)
        d_history.append(d_next)

    return data_stream, mu_history, Sigma_history, d_history

# %%
def single_simulation(rng, alpha_mu, alpha_sigma, alpha_d, rho_list, decay_list, drift_bound_list, number_dimension, epsilon=8000.0, SAMPLES_PER_T=20):
    """
    single simulation:
      - generate T history samples and real future in t=T+1
      - consider different parameter combinations
      - return average expected loss for each parameter combination
    """
    T = 10
    test_times = 8
    data_stream, mu_hist, Sigma_hist, d_hist = generate_data_stream(rng, T, alpha_mu, alpha_sigma, alpha_d, SAMPLES_PER_T)

    # training data: first T periods (flatten)
    Z_all = np.vstack(data_stream)
    X_all, y_all = Z_all[:, :-1], Z_all[:, -1]
    
    # ----------------------------------------
    # I. PRE-GENERATE the Test Scenarios (Drifts)
    # ----------------------------------------
    test_scenarios = []
    for _ in range(test_times):
        # (1) Feature mean drift (alpha_mu)
        # mu_{T+1} = mu_T + Uniform(-alpha_mu |mu_T|, +alpha_mu |mu_T|)
        drift_mu_range = alpha_mu * np.abs(mu_hist[-1])
        mu_next = mu_hist[-1] + rng.uniform(-drift_mu_range, drift_mu_range, size=mu_hist[-1].shape)

        # (2) Dependency vector drift (alpha_d)
        # d_{T+1} = d_T + Uniform(-alpha_d |d_T|, +alpha_d |d_T|)
        drift_d_range = alpha_d * np.abs(d_hist[-1])
        d_next = d_hist[-1] + rng.uniform(-drift_d_range, drift_d_range, size=d_hist[-1].shape)

        # (3) Covariance drift (alpha_Sigma)
        # G_t,ij ~ N(0, alpha_Sigma^2)
        G_T = rng.normal(0, alpha_sigma, size=Sigma_hist[-1].shape)
        # D_t = 1/2 * (G_t + G_t^T)
        D_T = 0.5 * (G_T + G_T.T)
        # Sigma_{T+1} = (I + 1/2 * D_t) * Sigma_T * (I + 1/2 * D_t)^T
        I_plus_half_D = np.eye(number_dimension) + 0.5 * D_T
        Sigma_next = I_plus_half_D @ Sigma_hist[-1] @ I_plus_half_D.T

        mu_y = float(mu_next @ d_next)
        Sigma_xy = Sigma_next @ d_next
        Sigma_yy = float(d_next.T @ Sigma_next @ d_next + epsilon**2)
        mu_joint = np.hstack([mu_next, mu_y])
        Sigma_joint = np.block([
            [Sigma_next, Sigma_xy.reshape(-1, 1)],
            [Sigma_xy.reshape(1, -1), np.array([[Sigma_yy]])]
        ])

        Z_nextstep = rng.multivariate_normal(mu_joint, Sigma_joint, size=SAMPLES_PER_T)
        X_nextstep, y_nextstep = Z_nextstep[:, :-1], Z_nextstep[:, -1]
        test_scenarios.append((X_nextstep, y_nextstep))

    losses = {}

    # ----------------------------------------
    # II. Weighted dro SVR (Training)
    # ----------------------------------------
    for rho in rho_list:
        for decay in decay_list:
            # sample weights
            time_idx = np.repeat(np.arange(T), len(data_stream[0]))
            pi = time_weights_from_indices(time_idx, now_t=T-1, decay=decay)

            # DRO-SVR training
            ell, upp = build_box_uncertainty(Z_all, qmin=0.01, qmax=0.99, eta=0.02)
            C1, c2, d = build_box_conic_from_bounds(ell, upp, X_all.shape[1])
            w_hat, _ = solve_dro_svr_cor33(X_all, y_all, C1, c2, d, pi, epsilon=epsilon, rho=rho)

            loss_list = []
            for X_nextstep, y_nextstep in test_scenarios:
                y_pred = X_nextstep @ w_hat
                loss_nextstep = eps_ins_loss(y_nextstep, y_pred, epsilon).mean()
                loss_list.append(loss_nextstep)
                
            losses[('dro_weighted', rho, decay)] = np.mean(loss_list)

    # ----------------------------------------
    # III. Weighted Empirical SVR (W-SAA)
    # ----------------------------------------
    for decay in decay_list:
        time_idx = np.repeat(np.arange(T), len(data_stream[0]))
        pi = time_weights_from_indices(time_idx, now_t=T-1, decay=decay)
        
        # Training
        w_hat_emp_w, _ = solve_empirical_svr_noreg(X_all, y_all, epsilon=epsilon, sample_weights=pi)

        # Testing
        loss_list = []
        for X_nextstep, y_nextstep in test_scenarios:
            y_pred = X_nextstep @ w_hat_emp_w
            loss_nextstep = eps_ins_loss(y_nextstep, y_pred, epsilon).mean()
            loss_list.append(loss_nextstep)
        
        losses[('empirical_weighted', 0.0, decay)] = np.mean(loss_list)

    # ----------------------------------------
    # IV. Unweighted Empirical SVR (SAA)
    # ----------------------------------------
    w_hat_emp_unw, _ = solve_empirical_svr_noreg(X_all, y_all, epsilon=epsilon, sample_weights=None)
    loss_list = []
    for X_nextstep, y_nextstep in test_scenarios:
        y_pred = X_nextstep @ w_hat_emp_unw
        loss_nextstep = eps_ins_loss(y_nextstep, y_pred, epsilon).mean()
        loss_list.append(loss_nextstep)
        
    losses[('empirical_unweighted', 0.0, 0.0)] = np.mean(loss_list)

    # ----------------------------------------
    # V. Optimal weights from Prop2
    # ----------------------------------------
    # choose eps_over_rho range
    for rho in rho_list:
        for drift_bound in drift_bound_list:
            eps_over_rho = rho / drift_bound
            pi_time = optimal_weights_prop2(T, eps_over_rho)
            pi_samples = np.repeat(pi_time, len(data_stream[0]))
            pi_samples = pi_samples / pi_samples.sum()

            # DRO-SVR training
            ell, upp = build_box_uncertainty(Z_all, qmin=0.01, qmax=0.99, eta=0.02)
            C1, c2, d = build_box_conic_from_bounds(ell, upp, X_all.shape[1])
            w_hat, _ = solve_dro_svr_cor33(X_all, y_all, C1, c2, d, pi_samples, epsilon=epsilon, rho=rho)

            loss_list = []
            for X7, y7 in test_scenarios:
                y_pred = X7 @ w_hat
                loss7 = eps_ins_loss(y7, y_pred, epsilon).mean()
                loss_list.append(loss7)
                
            losses[('dro_optimal_weighted', rho, drift_bound)] = np.mean(loss_list)

    return losses # Return all calculated losses

# %%
def run_multiple_simulations(num_runs=5, alpha_mu=None, alpha_sigma=None, alpha_d=None,
                             rho_list=None, decay_list=None, drift_bound_list=None, number_dimension=5, epsilon=8000.0, SAMPLES_PER_T=20):
    base_rng = np.random.default_rng(seed=42)
    
    dro_losses = []
    emp_weighted_losses = []
    emp_unweighted_losses = []
    prop2_losses = []

    for run in range(num_runs):
        print(f"Simulation {run+1}/{num_runs}")
        rng = np.random.default_rng(base_rng.integers(1e9)) 
        
        # results now contains all ('method', rho, decay) keys
        results = single_simulation(rng, alpha_mu, alpha_sigma, alpha_d, rho_list, decay_list, drift_bound_list, number_dimension, epsilon=epsilon, SAMPLES_PER_T=SAMPLES_PER_T)

        # 1. DRO-SVR: find ex-post optimal (rho, decay) among DRO results
        dro_results = {k: v for k, v in results.items() if k[0] == 'dro_weighted'} 
        best_dro_param = min(dro_results, key=dro_results.get) 
        best_dro_loss = dro_results[best_dro_param]
        dro_losses.append(best_dro_loss)
        print(f"  → DRO-SVR Best param: ρ={best_dro_param[1]}, decay={best_dro_param[2]}, loss={best_dro_loss:.2f}")

        # 2. Weighted Empirical SVR (W-SAA): find ex-post optimal decay
        emp_w_results = {k: v for k, v in results.items() if k[0] == 'empirical_weighted'}
        best_emp_w_param = min(emp_w_results, key=emp_w_results.get)
        best_emp_w_loss = emp_w_results[best_emp_w_param]
        emp_weighted_losses.append(best_emp_w_loss)
        print(f"  → W-SAA Best param: decay={best_emp_w_param[2]}, loss={best_emp_w_loss:.2f}")
        
        # 3. Unweighted Empirical SVR (Unweighted SAA)
        unw_loss = results[('empirical_unweighted', 0.0, 0.0)]
        emp_unweighted_losses.append(unw_loss)
        print(f"  → Unweighted SAA loss: {unw_loss:.2f}")

        # 4. Optimal Weights from Prop2
        prop2_results = {k: v for k, v in results.items() if k[0] == 'dro_optimal_weighted'}
        best_prop2_param = min(prop2_results, key=prop2_results.get)
        best_prop2_loss = prop2_results[best_prop2_param]
        prop2_losses.append(best_prop2_loss)
        print(f"  → Prop2 Best param: ρ={best_prop2_param[1]}, drift_bound={best_prop2_param[2]}, loss={best_prop2_loss:.2f}")

    return {
        'DRO-SVR': np.array(dro_losses),
        'W-SAA': np.array(emp_weighted_losses),
        'SAA': np.array(emp_unweighted_losses),
        'Prop2': np.array(prop2_losses)
    }

# %%
rho_list = [0.05, 0.1, 0.5, 1.0]
decay_list = [0.65, 0.75, 0.85, 0.95]
drift_bound_list = [0.001, 0.02, 0.04]
drift_param_list = np.logspace(-4, -1, num=10)

avg_results_all_methods = {'DRO-SVR': {}, 'W-SAA': {}, 'SAA': {}, 'Prop2': {}}
sem_results_all_methods = {'DRO-SVR': {}, 'W-SAA': {}, 'SAA': {}, 'Prop2': {}}

for dp in drift_param_list:
    print(f"\nRunning simulations for drift parameter {dp:.1e}...")

    losses_all = run_multiple_simulations(
        num_runs=10,
        alpha_mu=dp,
        alpha_sigma=dp,
        alpha_d=dp,
        rho_list=rho_list,
        decay_list=decay_list,
        drift_bound_list=drift_bound_list,
        number_dimension=5,
        epsilon=8000.0,
        SAMPLES_PER_T=20
    )

    dro_losses = np.array(losses_all['DRO-SVR'])
    w_saa_losses = np.array(losses_all['W-SAA'])
    saa_losses = np.array(losses_all['SAA'])
    prop2_losses = np.array(losses_all['Prop2'])

    n = len(dro_losses)
    baseline_mean = w_saa_losses.mean()

    dro_rel = dro_losses / baseline_mean
    w_saa_rel = w_saa_losses / baseline_mean
    saa_rel = saa_losses / baseline_mean
    prop2_rel = prop2_losses / baseline_mean

    avg_results_all_methods['DRO-SVR'][dp] = dro_rel.mean()
    sem_results_all_methods['DRO-SVR'][dp] = dro_rel.std(ddof=1) / np.sqrt(n)

    avg_results_all_methods['W-SAA'][dp] = w_saa_rel.mean()
    sem_results_all_methods['W-SAA'][dp] = w_saa_rel.std(ddof=1) / np.sqrt(n)

    avg_results_all_methods['SAA'][dp] = saa_rel.mean()
    sem_results_all_methods['SAA'][dp] = saa_rel.std(ddof=1) / np.sqrt(n)

    avg_results_all_methods['Prop2'][dp] = prop2_rel.mean()
    sem_results_all_methods['Prop2'][dp] = prop2_rel.std(ddof=1) / np.sqrt(n)

    print(
        f"Drift={dp:.1e} | "
        f"DRO mean={dro_rel.mean():.3f}±{dro_rel.std(ddof=1)/np.sqrt(n):.3f}, "
        f"W-SAA mean={w_saa_rel.mean():.3f}±{w_saa_rel.std(ddof=1)/np.sqrt(n):.3f}, "
        f"SAA mean={saa_rel.mean():.3f}±{saa_rel.std(ddof=1)/np.sqrt(n):.3f}, "
        f"Prop2 mean={prop2_rel.mean():.3f}±{prop2_rel.std(ddof=1)/np.sqrt(n):.3f}"
    )

# save results
with open("simulation_results_newmethod.pkl", "wb") as f:
    pickle.dump({
        "avg": avg_results_all_methods,
        "sem": sem_results_all_methods,
        "drift_list": drift_param_list
    }, f)
# Out:
# Running simulations for drift parameter 1.0e-04...
# Simulation 1/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.85, loss=1537.81
#   → W-SAA Best param: decay=0.85, loss=1557.64
#   → Unweighted SAA loss: 1562.40
#   → Prop2 Best param: ρ=0.05, drift_bound=0.001, loss=1539.97
# Simulation 2/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=1554.06
#   → W-SAA Best param: decay=0.95, loss=1551.81
#   → Unweighted SAA loss: 1543.45
#   → Prop2 Best param: ρ=0.05, drift_bound=0.001, loss=1558.19
# Simulation 3/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=1442.02
#   → W-SAA Best param: decay=0.85, loss=1435.41
#   → Unweighted SAA loss: 1449.29
#   → Prop2 Best param: ρ=0.05, drift_bound=0.001, loss=1442.03
# Simulation 4/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.95, loss=1361.41
#   → W-SAA Best param: decay=0.95, loss=1352.74
#   → Unweighted SAA loss: 1267.60
#   → Prop2 Best param: ρ=0.1, drift_bound=0.001, loss=1346.95
# Simulation 5/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.65, loss=1475.19
#   → W-SAA Best param: decay=0.65, loss=1563.55
#   → Unweighted SAA loss: 1785.92
#   → Prop2 Best param: ρ=0.1, drift_bound=0.02, loss=1517.13
# Simulation 6/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.85, loss=1233.96
#   → W-SAA Best param: decay=0.95, loss=1335.61
#   → Unweighted SAA loss: 1357.86
#   → Prop2 Best param: ρ=0.1, drift_bound=0.001, loss=1215.35
# Simulation 7/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.75, loss=1862.07
#   → W-SAA Best param: decay=0.95, loss=1786.65
#   → Unweighted SAA loss: 1788.15
#   → Prop2 Best param: ρ=0.1, drift_bound=0.001, loss=1862.92
# Simulation 8/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=1572.22
#   → W-SAA Best param: decay=0.95, loss=1568.57
#   → Unweighted SAA loss: 1584.27
#   → Prop2 Best param: ρ=0.05, drift_bound=0.001, loss=1551.13
# Simulation 9/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.65, loss=1276.10
#   → W-SAA Best param: decay=0.85, loss=1378.91
#   → Unweighted SAA loss: 1325.08
#   → Prop2 Best param: ρ=0.1, drift_bound=0.02, loss=1290.47
# Simulation 10/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.95, loss=1324.01
#   → W-SAA Best param: decay=0.65, loss=1337.08
#   → Unweighted SAA loss: 1372.95
#   → Prop2 Best param: ρ=0.1, drift_bound=0.001, loss=1310.92
# Drift=1.0e-04 | DRO mean=0.985±0.039, W-SAA mean=1.000±0.031, SAA mean=1.011±0.039, Prop2 mean=0.984±0.040
#
# Running simulations for drift parameter 2.2e-04...
# Simulation 1/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.85, loss=1536.60
#   → W-SAA Best param: decay=0.85, loss=1558.02
#   → Unweighted SAA loss: 1569.79
#   → Prop2 Best param: ρ=0.05, drift_bound=0.001, loss=1533.62
# Simulation 2/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=1553.82
#   → W-SAA Best param: decay=0.95, loss=1551.90
#   → Unweighted SAA loss: 1543.12
#   → Prop2 Best param: ρ=0.05, drift_bound=0.001, loss=1558.28
# Simulation 3/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=1441.43
#   → W-SAA Best param: decay=0.85, loss=1435.07
#   → Unweighted SAA loss: 1448.67
#   → Prop2 Best param: ρ=0.05, drift_bound=0.001, loss=1441.43
# Simulation 4/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.95, loss=1360.90
#   → W-SAA Best param: decay=0.95, loss=1351.76
#   → Unweighted SAA loss: 1267.23
#   → Prop2 Best param: ρ=0.1, drift_bound=0.001, loss=1346.00
# Simulation 5/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.65, loss=1475.49
#   → W-SAA Best param: decay=0.65, loss=1564.30
#   → Unweighted SAA loss: 1786.45
#   → Prop2 Best param: ρ=0.1, drift_bound=0.02, loss=1517.24
# Simulation 6/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.85, loss=1232.61
#   → W-SAA Best param: decay=0.95, loss=1333.56
#   → Unweighted SAA loss: 1355.14
#   → Prop2 Best param: ρ=0.1, drift_bound=0.001, loss=1215.10
# Simulation 7/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.75, loss=1861.21
#   → W-SAA Best param: decay=0.95, loss=1787.09
#   → Unweighted SAA loss: 1788.65
#   → Prop2 Best param: ρ=0.1, drift_bound=0.001, loss=1863.61
# Simulation 8/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=1572.78
#   → W-SAA Best param: decay=0.95, loss=1568.97
#   → Unweighted SAA loss: 1584.10
#   → Prop2 Best param: ρ=0.05, drift_bound=0.001, loss=1551.35
# Simulation 9/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.65, loss=1275.84
#   → W-SAA Best param: decay=0.85, loss=1378.85
#   → Unweighted SAA loss: 1324.47
#   → Prop2 Best param: ρ=0.1, drift_bound=0.02, loss=1290.21
# Simulation 10/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.95, loss=1323.07
#   → W-SAA Best param: decay=0.65, loss=1337.11
#   → Unweighted SAA loss: 1372.81
#   → Prop2 Best param: ρ=0.1, drift_bound=0.001, loss=1310.53
# Drift=2.2e-04 | DRO mean=0.984±0.039, W-SAA mean=1.000±0.031, SAA mean=1.012±0.039, Prop2 mean=0.984±0.040
#
# Running simulations for drift parameter 4.6e-04...
# Simulation 1/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=1530.67
#   → W-SAA Best param: decay=0.85, loss=1560.14
#   → Unweighted SAA loss: 1557.23
#   → Prop2 Best param: ρ=0.05, drift_bound=0.001, loss=1529.30
# Simulation 2/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=1553.42
#   → W-SAA Best param: decay=0.95, loss=1552.07
#   → Unweighted SAA loss: 1542.40
#   → Prop2 Best param: ρ=0.05, drift_bound=0.001, loss=1558.51
# Simulation 3/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=1440.20
#   → W-SAA Best param: decay=0.85, loss=1434.34
#   → Unweighted SAA loss: 1447.35
#   → Prop2 Best param: ρ=0.05, drift_bound=0.001, loss=1440.20
# Simulation 4/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.95, loss=1359.87
#   → W-SAA Best param: decay=0.95, loss=1349.66
#   → Unweighted SAA loss: 1266.20
#   → Prop2 Best param: ρ=0.1, drift_bound=0.001, loss=1343.89
# Simulation 5/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.65, loss=1476.13
#   → W-SAA Best param: decay=0.65, loss=1565.92
#   → Unweighted SAA loss: 1787.59
#   → Prop2 Best param: ρ=0.1, drift_bound=0.02, loss=1517.46
# Simulation 6/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.85, loss=1229.71
#   → W-SAA Best param: decay=0.95, loss=1329.14
#   → Unweighted SAA loss: 1349.53
#   → Prop2 Best param: ρ=0.1, drift_bound=0.001, loss=1214.59
# Simulation 7/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.95, loss=1858.51
#   → W-SAA Best param: decay=0.95, loss=1788.03
#   → Unweighted SAA loss: 1789.72
#   → Prop2 Best param: ρ=0.1, drift_bound=0.001, loss=1864.22
# Simulation 8/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=1587.15
#   → W-SAA Best param: decay=0.95, loss=1640.14
#   → Unweighted SAA loss: 1661.52
#   → Prop2 Best param: ρ=0.05, drift_bound=0.001, loss=1598.96
# Simulation 9/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.65, loss=1275.28
#   → W-SAA Best param: decay=0.85, loss=1378.72
#   → Unweighted SAA loss: 1323.11
#   → Prop2 Best param: ρ=0.1, drift_bound=0.02, loss=1289.66
# Simulation 10/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.95, loss=1321.05
#   → W-SAA Best param: decay=0.65, loss=1337.25
#   → Unweighted SAA loss: 1371.88
#   → Prop2 Best param: ρ=0.1, drift_bound=0.001, loss=1309.86
# Drift=4.6e-04 | DRO mean=0.980±0.039, W-SAA mean=1.000±0.032, SAA mean=1.011±0.040, Prop2 mean=0.982±0.040
#
# Running simulations for drift parameter 1.0e-03...
# Simulation 1/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=1513.13
#   → W-SAA Best param: decay=0.85, loss=1562.52
#   → Unweighted SAA loss: 1554.81
#   → Prop2 Best param: ρ=0.05, drift_bound=0.001, loss=1523.22
# Simulation 2/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=1552.56
#   → W-SAA Best param: decay=0.95, loss=1552.42
#   → Unweighted SAA loss: 1541.53
#   → Prop2 Best param: ρ=0.05, drift_bound=0.001, loss=1558.76
# Simulation 3/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=1437.89
#   → W-SAA Best param: decay=0.85, loss=1433.03
#   → Unweighted SAA loss: 1444.49
#   → Prop2 Best param: ρ=0.05, drift_bound=0.001, loss=1437.89
# Simulation 4/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.95, loss=1357.51
#   → W-SAA Best param: decay=0.95, loss=1345.10
#   → Unweighted SAA loss: 1265.05
#   → Prop2 Best param: ρ=0.1, drift_bound=0.001, loss=1339.32
# Simulation 5/10
# C:\Users\11864\AppData\Local\Temp\ipykernel_9656\1758410537.py:37: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   Z = rng.multivariate_normal(mu_joint, Sigma_joint, size=SAMPLES_PER_T)
# C:\Users\11864\AppData\Local\Temp\ipykernel_9656\3101202290.py:49: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   Z_nextstep = rng.multivariate_normal(mu_joint, Sigma_joint, size=SAMPLES_PER_T)
#   → DRO-SVR Best param: ρ=0.05, decay=0.65, loss=1493.25
#   → W-SAA Best param: decay=0.65, loss=1510.87
#   → Unweighted SAA loss: 1663.24
#   → Prop2 Best param: ρ=0.1, drift_bound=0.02, loss=1545.53
# Simulation 6/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.85, loss=1223.48
#   → W-SAA Best param: decay=0.95, loss=1319.64
#   → Unweighted SAA loss: 1335.11
#   → Prop2 Best param: ρ=0.1, drift_bound=0.001, loss=1213.42
# Simulation 7/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.95, loss=1848.46
#   → W-SAA Best param: decay=0.85, loss=1790.02
#   → Unweighted SAA loss: 1791.99
#   → Prop2 Best param: ρ=0.05, drift_bound=0.001, loss=1864.38
# Simulation 8/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=1706.79
#   → W-SAA Best param: decay=0.95, loss=1688.44
#   → Unweighted SAA loss: 1686.52
#   → Prop2 Best param: ρ=0.05, drift_bound=0.001, loss=1723.47
# Simulation 9/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.65, loss=1274.07
#   → W-SAA Best param: decay=0.95, loss=1375.51
#   → Unweighted SAA loss: 1320.80
#   → Prop2 Best param: ρ=0.1, drift_bound=0.02, loss=1288.49
# Simulation 10/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.95, loss=1312.07
#   → W-SAA Best param: decay=0.65, loss=1337.56
#   → Unweighted SAA loss: 1363.70
#   → Prop2 Best param: ρ=0.1, drift_bound=0.001, loss=1308.44
# Drift=1.0e-03 | DRO mean=0.987±0.042, W-SAA mean=1.000±0.034, SAA mean=1.003±0.038, Prop2 mean=0.992±0.043
#
# Running simulations for drift parameter 2.2e-03...
# Simulation 1/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=1504.32
#   → W-SAA Best param: decay=0.85, loss=1545.57
#   → Unweighted SAA loss: 1527.22
#   → Prop2 Best param: ρ=0.05, drift_bound=0.001, loss=1504.17
# Simulation 2/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=1551.24
#   → W-SAA Best param: decay=0.95, loss=1553.54
#   → Unweighted SAA loss: 1541.12
#   → Prop2 Best param: ρ=0.05, drift_bound=0.001, loss=1559.82
# Simulation 3/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=1435.79
#   → W-SAA Best param: decay=0.85, loss=1431.80
#   → Unweighted SAA loss: 1439.71
#   → Prop2 Best param: ρ=0.05, drift_bound=0.001, loss=1435.79
# Simulation 4/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.95, loss=1355.38
#   → W-SAA Best param: decay=0.95, loss=1336.47
#   → Unweighted SAA loss: 1263.82
#   → Prop2 Best param: ρ=0.1, drift_bound=0.001, loss=1337.15
# Simulation 5/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.85, loss=1561.93
#   → W-SAA Best param: decay=0.75, loss=1579.43
#   → Unweighted SAA loss: 1589.92
#   → Prop2 Best param: ρ=0.05, drift_bound=0.001, loss=1591.05
# Simulation 6/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.85, loss=1210.59
#   → W-SAA Best param: decay=0.95, loss=1306.32
#   → Unweighted SAA loss: 1318.80
#   → Prop2 Best param: ρ=0.1, drift_bound=0.001, loss=1210.26
# Simulation 7/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.85, loss=1844.72
#   → W-SAA Best param: decay=0.85, loss=1788.90
#   → Unweighted SAA loss: 1796.92
#   → Prop2 Best param: ρ=0.05, drift_bound=0.001, loss=1849.70
# Simulation 8/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=1792.17
#   → W-SAA Best param: decay=0.85, loss=1770.37
#   → Unweighted SAA loss: 1781.91
#   → Prop2 Best param: ρ=0.05, drift_bound=0.001, loss=1792.17
# Simulation 9/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.65, loss=1281.14
#   → W-SAA Best param: decay=0.95, loss=1368.16
#   → Unweighted SAA loss: 1319.81
#   → Prop2 Best param: ρ=0.1, drift_bound=0.001, loss=1290.35
# Simulation 10/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.95, loss=1308.44
#   → W-SAA Best param: decay=0.65, loss=1339.02
#   → Unweighted SAA loss: 1353.60
#   → Prop2 Best param: ρ=0.1, drift_bound=0.001, loss=1308.10
# Drift=2.2e-03 | DRO mean=0.988±0.044, W-SAA mean=1.000±0.037, SAA mean=0.994±0.040, Prop2 mean=0.991±0.045
#
# Running simulations for drift parameter 4.6e-03...
# Simulation 1/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=1500.61
#   → W-SAA Best param: decay=0.95, loss=1529.84
#   → Unweighted SAA loss: 1514.10
#   → Prop2 Best param: ρ=0.05, drift_bound=0.001, loss=1489.21
# Simulation 2/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.65, loss=1629.79
#   → W-SAA Best param: decay=0.85, loss=1592.55
#   → Unweighted SAA loss: 1660.00
#   → Prop2 Best param: ρ=0.1, drift_bound=0.02, loss=1655.90
# Simulation 3/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=1438.74
#   → W-SAA Best param: decay=0.95, loss=1433.55
#   → Unweighted SAA loss: 1442.27
#   → Prop2 Best param: ρ=0.05, drift_bound=0.001, loss=1439.06
# Simulation 4/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.95, loss=1341.06
#   → W-SAA Best param: decay=0.95, loss=1338.66
#   → Unweighted SAA loss: 1270.45
#   → Prop2 Best param: ρ=0.1, drift_bound=0.001, loss=1313.59
# Simulation 5/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.85, loss=1494.83
#   → W-SAA Best param: decay=0.75, loss=1535.46
#   → Unweighted SAA loss: 1551.76
#   → Prop2 Best param: ρ=0.05, drift_bound=0.001, loss=1562.56
# Simulation 6/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.85, loss=1187.81
#   → W-SAA Best param: decay=0.95, loss=1284.69
#   → Unweighted SAA loss: 1306.25
#   → Prop2 Best param: ρ=0.1, drift_bound=0.001, loss=1201.42
# Simulation 7/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.65, loss=1790.50
#   → W-SAA Best param: decay=0.65, loss=1781.60
#   → Unweighted SAA loss: 1825.84
#   → Prop2 Best param: ρ=0.1, drift_bound=0.02, loss=1755.58
# Simulation 8/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=1794.55
#   → W-SAA Best param: decay=0.75, loss=1753.03
#   → Unweighted SAA loss: 1766.68
#   → Prop2 Best param: ρ=0.05, drift_bound=0.001, loss=1782.95
# Simulation 9/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.95, loss=1273.26
#   → W-SAA Best param: decay=0.95, loss=1365.29
#   → Unweighted SAA loss: 1322.31
#   → Prop2 Best param: ρ=0.1, drift_bound=0.001, loss=1271.86
# Simulation 10/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.95, loss=1508.26
#   → W-SAA Best param: decay=0.95, loss=1497.28
#   → Unweighted SAA loss: 1482.81
#   → Prop2 Best param: ρ=0.1, drift_bound=0.001, loss=1498.17
# Drift=4.6e-03 | DRO mean=0.990±0.042, W-SAA mean=1.000±0.035, SAA mean=1.002±0.040, Prop2 mean=0.991±0.041
#
# Running simulations for drift parameter 1.0e-02...
# Simulation 1/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=1525.24
#   → W-SAA Best param: decay=0.95, loss=1530.39
#   → Unweighted SAA loss: 1542.27
#   → Prop2 Best param: ρ=0.05, drift_bound=0.001, loss=1524.75
# Simulation 2/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=1596.18
#   → W-SAA Best param: decay=0.95, loss=1668.58
#   → Unweighted SAA loss: 1646.51
#   → Prop2 Best param: ρ=0.05, drift_bound=0.001, loss=1596.18
# Simulation 3/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=1460.46
#   → W-SAA Best param: decay=0.95, loss=1468.21
#   → Unweighted SAA loss: 1470.05
#   → Prop2 Best param: ρ=0.05, drift_bound=0.001, loss=1461.39
# Simulation 4/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=1354.11
#   → W-SAA Best param: decay=0.95, loss=1354.45
#   → Unweighted SAA loss: 1293.40
#   → Prop2 Best param: ρ=0.1, drift_bound=0.001, loss=1226.10
# Simulation 5/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.85, loss=1551.06
#   → W-SAA Best param: decay=0.75, loss=1535.34
#   → Unweighted SAA loss: 1564.91
#   → Prop2 Best param: ρ=0.05, drift_bound=0.001, loss=1589.23
# Simulation 6/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=1458.96
#   → W-SAA Best param: decay=0.95, loss=1479.35
#   → Unweighted SAA loss: 1450.40
#   → Prop2 Best param: ρ=0.05, drift_bound=0.001, loss=1459.75
# Simulation 7/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=1783.84
#   → W-SAA Best param: decay=0.75, loss=1765.04
#   → Unweighted SAA loss: 1806.33
#   → Prop2 Best param: ρ=0.1, drift_bound=0.001, loss=1779.57
# Simulation 8/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=1521.03
#   → W-SAA Best param: decay=0.95, loss=1515.77
#   → Unweighted SAA loss: 1507.05
#   → Prop2 Best param: ρ=0.05, drift_bound=0.001, loss=1520.91
# Simulation 9/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.65, loss=1514.08
#   → W-SAA Best param: decay=0.65, loss=1511.77
#   → Unweighted SAA loss: 1542.73
#   → Prop2 Best param: ρ=0.05, drift_bound=0.001, loss=1533.91
# Simulation 10/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.75, loss=1502.13
#   → W-SAA Best param: decay=0.95, loss=1471.14
#   → Unweighted SAA loss: 1460.35
#   → Prop2 Best param: ρ=0.1, drift_bound=0.001, loss=1502.80
# Drift=1.0e-02 | DRO mean=0.998±0.023, W-SAA mean=1.000±0.023, SAA mean=0.999±0.028, Prop2 mean=0.993±0.029
#
# Running simulations for drift parameter 2.2e-02...
# Simulation 1/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.65, loss=1966.13
#   → W-SAA Best param: decay=0.65, loss=1718.32
#   → Unweighted SAA loss: 2178.08
#   → Prop2 Best param: ρ=0.1, drift_bound=0.02, loss=1867.69
# Simulation 2/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.95, loss=1860.86
#   → W-SAA Best param: decay=0.85, loss=1849.83
#   → Unweighted SAA loss: 1840.24
#   → Prop2 Best param: ρ=0.05, drift_bound=0.001, loss=1855.38
# Simulation 3/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.85, loss=1557.32
#   → W-SAA Best param: decay=0.95, loss=1609.34
#   → Unweighted SAA loss: 1606.99
#   → Prop2 Best param: ρ=0.1, drift_bound=0.001, loss=1568.60
# Simulation 4/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.95, loss=1341.29
#   → W-SAA Best param: decay=0.95, loss=1310.62
#   → Unweighted SAA loss: 1299.50
#   → Prop2 Best param: ρ=0.1, drift_bound=0.001, loss=1299.79
# Simulation 5/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=1539.37
#   → W-SAA Best param: decay=0.95, loss=1529.68
#   → Unweighted SAA loss: 1530.82
#   → Prop2 Best param: ρ=0.05, drift_bound=0.001, loss=1560.53
# Simulation 6/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=2105.88
#   → W-SAA Best param: decay=0.65, loss=1982.52
#   → Unweighted SAA loss: 2088.48
#   → Prop2 Best param: ρ=0.05, drift_bound=0.02, loss=1911.39
# Simulation 7/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.95, loss=1743.85
#   → W-SAA Best param: decay=0.65, loss=1770.89
#   → Unweighted SAA loss: 1944.45
#   → Prop2 Best param: ρ=0.1, drift_bound=0.001, loss=1743.63
# Simulation 8/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=1843.50
#   → W-SAA Best param: decay=0.95, loss=1679.26
#   → Unweighted SAA loss: 1636.72
#   → Prop2 Best param: ρ=0.05, drift_bound=0.001, loss=1838.87
# Simulation 9/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.95, loss=1419.06
#   → W-SAA Best param: decay=0.95, loss=1424.36
#   → Unweighted SAA loss: 1370.20
#   → Prop2 Best param: ρ=0.05, drift_bound=0.001, loss=1387.97
# Simulation 10/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.75, loss=1303.95
#   → W-SAA Best param: decay=0.65, loss=1386.56
#   → Unweighted SAA loss: 1417.16
#   → Prop2 Best param: ρ=0.1, drift_bound=0.001, loss=1305.97
# Drift=2.2e-02 | DRO mean=1.026±0.054, W-SAA mean=1.000±0.042, SAA mean=1.040±0.060, Prop2 mean=1.005±0.047
#
# Running simulations for drift parameter 4.6e-02...
# Simulation 1/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.65, loss=3347.98
#   → W-SAA Best param: decay=0.65, loss=3044.39
#   → Unweighted SAA loss: 5228.95
#   → Prop2 Best param: ρ=0.1, drift_bound=0.04, loss=2120.21
# Simulation 2/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=2054.35
#   → W-SAA Best param: decay=0.65, loss=2294.38
#   → Unweighted SAA loss: 2294.60
#   → Prop2 Best param: ρ=0.05, drift_bound=0.001, loss=2015.57
# Simulation 3/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.65, loss=1966.85
#   → W-SAA Best param: decay=0.65, loss=2128.89
#   → Unweighted SAA loss: 2144.35
#   → Prop2 Best param: ρ=0.1, drift_bound=0.02, loss=1969.06
# Simulation 4/10
#   → DRO-SVR Best param: ρ=0.5, decay=0.95, loss=1544.67
#   → W-SAA Best param: decay=0.95, loss=1627.52
#   → Unweighted SAA loss: 1648.08
#   → Prop2 Best param: ρ=0.5, drift_bound=0.001, loss=1523.78
# Simulation 5/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.95, loss=2106.87
#   → W-SAA Best param: decay=0.65, loss=2043.24
#   → Unweighted SAA loss: 2055.02
#   → Prop2 Best param: ρ=0.05, drift_bound=0.04, loss=1824.33
# Simulation 6/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.65, loss=2618.81
#   → W-SAA Best param: decay=0.65, loss=2220.61
#   → Unweighted SAA loss: 3064.92
#   → Prop2 Best param: ρ=0.05, drift_bound=0.02, loss=2152.07
# Simulation 7/10
#   → DRO-SVR Best param: ρ=0.5, decay=0.95, loss=1809.40
#   → W-SAA Best param: decay=0.65, loss=2038.04
#   → Unweighted SAA loss: 2867.37
#   → Prop2 Best param: ρ=0.5, drift_bound=0.001, loss=1770.65
# Simulation 8/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.85, loss=1708.74
#   → W-SAA Best param: decay=0.95, loss=1729.12
#   → Unweighted SAA loss: 1729.12
#   → Prop2 Best param: ρ=0.05, drift_bound=0.001, loss=1717.89
# Simulation 9/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.75, loss=1564.90
#   → W-SAA Best param: decay=0.85, loss=1579.19
#   → Unweighted SAA loss: 1586.24
#   → Prop2 Best param: ρ=0.05, drift_bound=0.001, loss=1631.05
# Simulation 10/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.95, loss=1424.47
#   → W-SAA Best param: decay=0.95, loss=1530.39
#   → Unweighted SAA loss: 1507.89
#   → Prop2 Best param: ρ=0.1, drift_bound=0.001, loss=1408.22
# Drift=4.6e-02 | DRO mean=0.996±0.091, W-SAA mean=1.000±0.071, SAA mean=1.192±0.175, Prop2 mean=0.896±0.039
#
# Running simulations for drift parameter 1.0e-01...
# Simulation 1/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.65, loss=8835.25
#   → W-SAA Best param: decay=0.65, loss=9009.72
#   → Unweighted SAA loss: 13122.22
#   → Prop2 Best param: ρ=0.1, drift_bound=0.02, loss=7073.07
# Simulation 2/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.95, loss=3393.26
#   → W-SAA Best param: decay=0.95, loss=3583.04
#   → Unweighted SAA loss: 3537.41
#   → Prop2 Best param: ρ=0.05, drift_bound=0.04, loss=3219.15
# Simulation 3/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.65, loss=4132.21
#   → W-SAA Best param: decay=0.65, loss=4112.74
#   → Unweighted SAA loss: 4292.60
#   → Prop2 Best param: ρ=0.05, drift_bound=0.02, loss=3974.68
# Simulation 4/10
#   → DRO-SVR Best param: ρ=0.5, decay=0.95, loss=2223.26
#   → W-SAA Best param: decay=0.85, loss=2889.70
#   → Unweighted SAA loss: 3024.77
#   → Prop2 Best param: ρ=0.5, drift_bound=0.04, loss=2216.02
# Simulation 5/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.65, loss=3057.34
#   → W-SAA Best param: decay=0.65, loss=3000.84
#   → Unweighted SAA loss: 2973.82
#   → Prop2 Best param: ρ=0.05, drift_bound=0.02, loss=2967.72
# Simulation 6/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.65, loss=5983.67
#   → W-SAA Best param: decay=0.65, loss=5037.22
#   → Unweighted SAA loss: 7804.26
#   → Prop2 Best param: ρ=0.05, drift_bound=0.04, loss=4137.59
# Simulation 7/10
#   → DRO-SVR Best param: ρ=1.0, decay=0.85, loss=2495.14
#   → W-SAA Best param: decay=0.85, loss=4154.65
#   → Unweighted SAA loss: 5297.77
#   → Prop2 Best param: ρ=1.0, drift_bound=0.02, loss=2535.95
# Simulation 8/10
#   → DRO-SVR Best param: ρ=0.1, decay=0.75, loss=2103.48
#   → W-SAA Best param: decay=0.75, loss=2167.49
#   → Unweighted SAA loss: 2306.74
#   → Prop2 Best param: ρ=0.1, drift_bound=0.02, loss=2035.79
# Simulation 9/10
#   → DRO-SVR Best param: ρ=0.05, decay=0.75, loss=1702.07
#   → W-SAA Best param: decay=0.75, loss=1701.93
#   → Unweighted SAA loss: 1786.90
#   → Prop2 Best param: ρ=0.05, drift_bound=0.001, loss=1757.09
# Simulation 10/10
#   → DRO-SVR Best param: ρ=0.5, decay=0.85, loss=1550.50
#   → W-SAA Best param: decay=0.95, loss=1897.99
#   → Unweighted SAA loss: 2032.59
#   → Prop2 Best param: ρ=0.5, drift_bound=0.04, loss=1542.47
# Drift=1.0e-01 | DRO mean=0.945±0.192, W-SAA mean=1.000±0.180, SAA mean=1.230±0.294, Prop2 mean=0.838±0.138

# %%
with open("simulation_results_newmethod.pkl", "rb") as f:
    data = pickle.load(f)

drift_params_array = np.array(list(avg_results_all_methods['DRO-SVR'].keys()))

dro_mean = np.array(list(avg_results_all_methods['DRO-SVR'].values()))
w_saa_mean = np.array(list(avg_results_all_methods['W-SAA'].values()))
saa_mean = np.array(list(avg_results_all_methods['SAA'].values()))
prop2_mean = np.array(list(avg_results_all_methods['Prop2'].values()))

dro_sem = np.array(list(sem_results_all_methods['DRO-SVR'].values()))
w_saa_sem = np.array(list(sem_results_all_methods['W-SAA'].values()))
saa_sem = np.array(list(sem_results_all_methods['SAA'].values()))
prop2_sem = np.array(list(sem_results_all_methods['Prop2'].values()))

plt.figure(figsize=(8,5))

# DRO-SVR
plt.plot(drift_params_array, dro_mean, marker='o', color='tab:blue', label='DRO-SVR')
plt.fill_between(drift_params_array, dro_mean - dro_sem, dro_mean + dro_sem,
                 color='tab:blue', alpha=0.2)

# W-SAA
plt.plot(drift_params_array, w_saa_mean, marker='s', linestyle='--',
         color='tab:orange', label='W-SAA (Weighted Empirical, Base)')
plt.fill_between(drift_params_array, w_saa_mean - w_saa_sem, w_saa_mean + w_saa_sem,
                 color='tab:orange', alpha=0.2)

# SAA
plt.plot(drift_params_array, saa_mean, marker='^', color='tab:green', label='SAA (Unweighted Empirical)')
plt.fill_between(drift_params_array, saa_mean - saa_sem, saa_mean + saa_sem,
                 color='tab:green', alpha=0.2)

# Prop2
plt.plot(drift_params_array, prop2_mean, marker='x', linestyle='-.',
         color='tab:red', label='DRO-SVR with Prop2 Weights')
plt.fill_between(drift_params_array, prop2_mean - prop2_sem, prop2_mean + prop2_sem,
                 color='tab:red', alpha=0.2)

plt.axhline(y=1.0, color='gray', linestyle=':', linewidth=1)
plt.xscale('log')
plt.xlim(min(drift_params_array), max(drift_params_array))
plt.xlabel("Drift parameter intensity")
plt.ylabel("Average Ex-Post Optimal Loss (relative to W-SAA)")
plt.title("Performance Comparison vs Drift Strength (Relative Loss)")
plt.legend()
plt.grid(True, which='both', ls=':')
plt.show()
